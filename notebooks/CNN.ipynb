# %%
from datasets import load_dataset
import numpy as np
from tqdm import tqdm
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
import os, math, random
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth activado.")
    except Exception as e:
        print("No se pudo activar memory growth:", e)

try:
    tf.config.threading.set_intra_op_parallelism_threads(2)
    tf.config.threading.set_inter_op_parallelism_threads(2)
    print("Hilos CPU limitados a 2/2.")
except Exception:
    pass

try:
    tf.config.optimizer.set_jit(True)
    print("XLA activado.")
except Exception:
    pass

# ==== (opcional) Desactiva mixed precision por estabilidad ====
# Si quieres probar luego: comenta la línea inferior y activa mixed precision.
tf.keras.mixed_precision.set_global_policy("float32")
print("Precision: float32")
# Out:
# GPU memory growth activado.
# Hilos CPU limitados a 2/2.
# XLA activado.
# Precision: float32

# %%
dataset = load_dataset("Hemg/AI-Generated-vs-Real-Images-Datasets", split="train")
print(dataset)
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 152710
# })

# %%
labels = np.array([int(dataset[i]["label"]) for i in tqdm(range(len(dataset)), desc="Leyendo etiquetas")])
# Out:
# Leyendo etiquetas: 100%|██████████| 152710/152710 [01:39<00:00, 1532.89it/s]

# %%
idx_full = np.arange(len(dataset))
idx_sub, _idx_discard, y_sub, _y_discard = train_test_split(
    idx_full, labels, test_size=0.7, stratify=labels, random_state=42
)
print(f"Usando ~30% del dataset: {len(idx_sub)} de {len(dataset)}")
# Out:
# Usando ~30% del dataset: 45813 de 152710

# %%
idx_train, idx_tmp, y_train, y_tmp = train_test_split(
    idx_sub, y_sub, test_size=0.2, stratify=y_sub, random_state=42
)
idx_val, idx_test, y_val, y_test = train_test_split(
    idx_tmp, y_tmp, test_size=0.5, stratify=y_tmp, random_state=42
)

idx_train = [int(i) for i in idx_train]
idx_val   = [int(i) for i in idx_val]
idx_test  = [int(i) for i in idx_test]

print(f"Train: {len(idx_train)} | Val: {len(idx_val)} | Test: {len(idx_test)}")
# Out:
# Train: 36650 | Val: 4581 | Test: 4582

# %%
IMG_SIZE = 128

def preprocess_pil(pil_img: Image.Image, size=IMG_SIZE):
    img = ImageOps.exif_transpose(pil_img)
    if img.mode == "P":
        if "transparency" in img.info:
            img = img.convert("RGBA")
        else:
            img = img.convert("RGB")
    if img.mode in ("RGBA", "LA"):
        bg = Image.new("RGBA", img.size, (255, 255, 255, 255))
        img = Image.alpha_composite(bg, img.convert("RGBA")).convert("RGB")
    if img.mode != "RGB":
        img = img.convert("RGB")
    img = ImageOps.fit(img, (size, size), method=Image.BILINEAR)
    arr = np.asarray(img, dtype=np.uint8).astype("float32") / 255.0
    return arr

# %%
def _py_load_and_process(i):
    i = int(i)
    sample = dataset[i]
    x = preprocess_pil(sample["image"], IMG_SIZE)
    y = np.float32(sample["label"])  # 0.0 ó 1.0
    return x, y

def make_tf_dataset(indices, batch_size=32, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices(indices)
    if shuffle:
        ds = ds.shuffle(buffer_size=min(4096, len(indices)), reshuffle_each_iteration=True)

    def tf_loader(i):
        x, y = tf.py_function(func=_py_load_and_process, inp=[i], Tout=(tf.float32, tf.float32))
        x.set_shape((IMG_SIZE, IMG_SIZE, 3))
        y.set_shape(())
        return x, y

    ds = ds.map(tf_loader, num_parallel_calls=4)
    ds = ds.batch(batch_size, drop_remainder=False)
    options = tf.data.Options()
    options.experimental_deterministic = False
    ds = ds.with_options(options)
    ds = ds.prefetch(2)
    return ds

BATCH_SIZE = 32
train_ds = make_tf_dataset(idx_train, batch_size=BATCH_SIZE, shuffle=True)
val_ds   = make_tf_dataset(idx_val,   batch_size=BATCH_SIZE, shuffle=False)
test_ds  = make_tf_dataset(idx_test,  batch_size=BATCH_SIZE, shuffle=False)

# %%
def build_model(input_shape=(IMG_SIZE, IMG_SIZE, 3), train_base=False, dropout=0.3, alpha=0.35):
    inputs = layers.Input(shape=input_shape)

    # Augmentaciones ligeras
    x = layers.RandomFlip("horizontal")(inputs)
    x = layers.RandomContrast(0.1)(x)
    x = layers.RandomZoom(0.05)(x)
    x = layers.RandomRotation(0.02)(x)

    # Escala a [-1,1] (MobileNetV2)
    x = layers.Rescaling(1./127.5, offset=-1.0)(x)

    base = MobileNetV2(input_tensor=x, include_top=False, weights="imagenet", alpha=alpha)
    base.trainable = train_base

    x = layers.GlobalAveragePooling2D()(base.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)
    # Binaria: 1 logit -> sigmoid
    out = layers.Dense(1, activation="sigmoid", dtype="float32")(x)
    return models.Model(inputs, out)

model = build_model()
# Out:
# /tmp/ipython-input-666593929.py:13: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = MobileNetV2(input_tensor=x, include_top=False, weights="imagenet", alpha=alpha)

# %%
counts = np.bincount(y_sub)
ratio = counts.max() / counts.min()
if ratio > 1.5:
    total = counts.sum(); unique = np.arange(len(counts))
    class_weight = {int(k): float(total / (len(unique) * v)) for k, v in zip(unique, counts)}
    print(f"Usaré class_weight (ratio={ratio:.2f}):", class_weight)
else:
    class_weight = None
    print(f"Dataset balanceado (ratio={ratio:.2f}); NO usaré class_weight.")
# Out:
# Dataset balanceado (ratio=1.13); NO usaré class_weight.

# %%
class WarmupThenCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr, steps_per_epoch, total_epochs, warmup_epochs=1):
        super().__init__()
        self.base_lr = base_lr
        self.spe = tf.cast(steps_per_epoch, tf.float32)
        self.total_steps = tf.cast(steps_per_epoch * total_epochs, tf.float32)
        self.warmup_steps = tf.cast(steps_per_epoch * warmup_epochs, tf.float32)
        self.decay_steps = tf.maximum(self.total_steps - self.warmup_steps, 1.)

    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        # warmup lineal
        def warm():
            return self.base_lr * (step + 1.) / tf.maximum(self.warmup_steps, 1.)
        # cosine decay
        def cosine():
            t = (step - self.warmup_steps) / self.decay_steps
            t = tf.clip_by_value(t, 0., 1.)
            return 0.5 * self.base_lr * (1 + tf.cos(tf.constant(math.pi) * t))
        return tf.cond(step < self.warmup_steps, warm, cosine)

steps_per_epoch = max(1, math.ceil(len(idx_train) / BATCH_SIZE))
TOTAL_EPOCHS = 6
WARMUP_EPOCHS = 1
BASE_LR = 1e-3

lr_schedule = WarmupThenCosine(base_lr=BASE_LR, steps_per_epoch=steps_per_epoch,
                               total_epochs=TOTAL_EPOCHS, warmup_epochs=WARMUP_EPOCHS)

optimizer = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=1e-4)

# Compilación binaria (sin one-hot, estable)
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

print(model.summary(line_length=120))
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ┃ Layer (type)                      ┃ Output Shape                 ┃           Param # ┃ Connected to
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━
# │ input_layer_6 (InputLayer)        │ (None, 128, 128, 3)          │                 0 │ -
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ random_flip_5 (RandomFlip)        │ (None, 128, 128, 3)          │                 0 │ input_layer_6[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ random_contrast_5                 │ (None, 128, 128, 3)          │                 0 │ random_flip_5[0][0]
# │ (RandomContrast)                  │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ random_zoom_4 (RandomZoom)        │ (None, 128, 128, 3)          │                 0 │ random_contrast_5[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ random_rotation_4                 │ (None, 128, 128, 3)          │                 0 │ random_zoom_4[0][0]
# │ (RandomRotation)                  │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ rescaling_6 (Rescaling)           │ (None, 128, 128, 3)          │                 0 │ random_rotation_4[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ Conv1 (Conv2D)                    │ (None, 64, 64, 16)           │               432 │ rescaling_6[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ bn_Conv1 (BatchNormalization)     │ (None, 64, 64, 16)           │                64 │ Conv1[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ Conv1_relu (ReLU)                 │ (None, 64, 64, 16)           │                 0 │ bn_Conv1[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ expanded_conv_depthwise           │ (None, 64, 64, 16)           │               144 │ Conv1_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ expanded_conv_depthwise_BN        │ (None, 64, 64, 16)           │                64 │ expanded_conv_depthwise[0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ expanded_conv_depthwise_relu      │ (None, 64, 64, 16)           │                 0 │ expanded_conv_depthwise_BN
# │ (ReLU)                            │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ expanded_conv_project (Conv2D)    │ (None, 64, 64, 8)            │               128 │ expanded_conv_depthwise_re
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ expanded_conv_project_BN          │ (None, 64, 64, 8)            │                32 │ expanded_conv_project[0][0
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_expand (Conv2D)           │ (None, 64, 64, 48)           │               384 │ expanded_conv_project_BN[0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_expand_BN                 │ (None, 64, 64, 48)           │               192 │ block_1_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_expand_relu (ReLU)        │ (None, 64, 64, 48)           │                 0 │ block_1_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_pad (ZeroPadding2D)       │ (None, 65, 65, 48)           │                 0 │ block_1_expand_relu[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_depthwise                 │ (None, 32, 32, 48)           │               432 │ block_1_pad[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_depthwise_BN              │ (None, 32, 32, 48)           │               192 │ block_1_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_depthwise_relu (ReLU)     │ (None, 32, 32, 48)           │                 0 │ block_1_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_project (Conv2D)          │ (None, 32, 32, 8)            │               384 │ block_1_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_1_project_BN                │ (None, 32, 32, 8)            │                32 │ block_1_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_expand (Conv2D)           │ (None, 32, 32, 48)           │               384 │ block_1_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_expand_BN                 │ (None, 32, 32, 48)           │               192 │ block_2_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_expand_relu (ReLU)        │ (None, 32, 32, 48)           │                 0 │ block_2_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_depthwise                 │ (None, 32, 32, 48)           │               432 │ block_2_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_depthwise_BN              │ (None, 32, 32, 48)           │               192 │ block_2_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_depthwise_relu (ReLU)     │ (None, 32, 32, 48)           │                 0 │ block_2_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_project (Conv2D)          │ (None, 32, 32, 8)            │               384 │ block_2_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_project_BN                │ (None, 32, 32, 8)            │                32 │ block_2_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_2_add (Add)                 │ (None, 32, 32, 8)            │                 0 │ block_1_project_BN[0][0],
# │                                   │                              │                   │ block_2_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_expand (Conv2D)           │ (None, 32, 32, 48)           │               384 │ block_2_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_expand_BN                 │ (None, 32, 32, 48)           │               192 │ block_3_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_expand_relu (ReLU)        │ (None, 32, 32, 48)           │                 0 │ block_3_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_pad (ZeroPadding2D)       │ (None, 33, 33, 48)           │                 0 │ block_3_expand_relu[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_depthwise                 │ (None, 16, 16, 48)           │               432 │ block_3_pad[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_depthwise_BN              │ (None, 16, 16, 48)           │               192 │ block_3_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_depthwise_relu (ReLU)     │ (None, 16, 16, 48)           │                 0 │ block_3_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_project (Conv2D)          │ (None, 16, 16, 16)           │               768 │ block_3_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_3_project_BN                │ (None, 16, 16, 16)           │                64 │ block_3_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_expand (Conv2D)           │ (None, 16, 16, 96)           │             1,536 │ block_3_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_expand_BN                 │ (None, 16, 16, 96)           │               384 │ block_4_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_expand_relu (ReLU)        │ (None, 16, 16, 96)           │                 0 │ block_4_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_depthwise                 │ (None, 16, 16, 96)           │               864 │ block_4_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_depthwise_BN              │ (None, 16, 16, 96)           │               384 │ block_4_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_depthwise_relu (ReLU)     │ (None, 16, 16, 96)           │                 0 │ block_4_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_project (Conv2D)          │ (None, 16, 16, 16)           │             1,536 │ block_4_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_project_BN                │ (None, 16, 16, 16)           │                64 │ block_4_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_4_add (Add)                 │ (None, 16, 16, 16)           │                 0 │ block_3_project_BN[0][0],
# │                                   │                              │                   │ block_4_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_expand (Conv2D)           │ (None, 16, 16, 96)           │             1,536 │ block_4_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_expand_BN                 │ (None, 16, 16, 96)           │               384 │ block_5_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_expand_relu (ReLU)        │ (None, 16, 16, 96)           │                 0 │ block_5_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_depthwise                 │ (None, 16, 16, 96)           │               864 │ block_5_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_depthwise_BN              │ (None, 16, 16, 96)           │               384 │ block_5_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_depthwise_relu (ReLU)     │ (None, 16, 16, 96)           │                 0 │ block_5_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_project (Conv2D)          │ (None, 16, 16, 16)           │             1,536 │ block_5_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_project_BN                │ (None, 16, 16, 16)           │                64 │ block_5_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_5_add (Add)                 │ (None, 16, 16, 16)           │                 0 │ block_4_add[0][0],
# │                                   │                              │                   │ block_5_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_expand (Conv2D)           │ (None, 16, 16, 96)           │             1,536 │ block_5_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_expand_BN                 │ (None, 16, 16, 96)           │               384 │ block_6_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_expand_relu (ReLU)        │ (None, 16, 16, 96)           │                 0 │ block_6_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_pad (ZeroPadding2D)       │ (None, 17, 17, 96)           │                 0 │ block_6_expand_relu[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_depthwise                 │ (None, 8, 8, 96)             │               864 │ block_6_pad[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_depthwise_BN              │ (None, 8, 8, 96)             │               384 │ block_6_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_depthwise_relu (ReLU)     │ (None, 8, 8, 96)             │                 0 │ block_6_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_project (Conv2D)          │ (None, 8, 8, 24)             │             2,304 │ block_6_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_6_project_BN                │ (None, 8, 8, 24)             │                96 │ block_6_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_expand (Conv2D)           │ (None, 8, 8, 144)            │             3,456 │ block_6_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_expand_BN                 │ (None, 8, 8, 144)            │               576 │ block_7_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_expand_relu (ReLU)        │ (None, 8, 8, 144)            │                 0 │ block_7_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_depthwise                 │ (None, 8, 8, 144)            │             1,296 │ block_7_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_depthwise_BN              │ (None, 8, 8, 144)            │               576 │ block_7_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_depthwise_relu (ReLU)     │ (None, 8, 8, 144)            │                 0 │ block_7_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_project (Conv2D)          │ (None, 8, 8, 24)             │             3,456 │ block_7_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_project_BN                │ (None, 8, 8, 24)             │                96 │ block_7_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_7_add (Add)                 │ (None, 8, 8, 24)             │                 0 │ block_6_project_BN[0][0],
# │                                   │                              │                   │ block_7_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_expand (Conv2D)           │ (None, 8, 8, 144)            │             3,456 │ block_7_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_expand_BN                 │ (None, 8, 8, 144)            │               576 │ block_8_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_expand_relu (ReLU)        │ (None, 8, 8, 144)            │                 0 │ block_8_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_depthwise                 │ (None, 8, 8, 144)            │             1,296 │ block_8_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_depthwise_BN              │ (None, 8, 8, 144)            │               576 │ block_8_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_depthwise_relu (ReLU)     │ (None, 8, 8, 144)            │                 0 │ block_8_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_project (Conv2D)          │ (None, 8, 8, 24)             │             3,456 │ block_8_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_project_BN                │ (None, 8, 8, 24)             │                96 │ block_8_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_8_add (Add)                 │ (None, 8, 8, 24)             │                 0 │ block_7_add[0][0],
# │                                   │                              │                   │ block_8_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_expand (Conv2D)           │ (None, 8, 8, 144)            │             3,456 │ block_8_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_expand_BN                 │ (None, 8, 8, 144)            │               576 │ block_9_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_expand_relu (ReLU)        │ (None, 8, 8, 144)            │                 0 │ block_9_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_depthwise                 │ (None, 8, 8, 144)            │             1,296 │ block_9_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_depthwise_BN              │ (None, 8, 8, 144)            │               576 │ block_9_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_depthwise_relu (ReLU)     │ (None, 8, 8, 144)            │                 0 │ block_9_depthwise_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_project (Conv2D)          │ (None, 8, 8, 24)             │             3,456 │ block_9_depthwise_relu[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_project_BN                │ (None, 8, 8, 24)             │                96 │ block_9_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_9_add (Add)                 │ (None, 8, 8, 24)             │                 0 │ block_8_add[0][0],
# │                                   │                              │                   │ block_9_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_expand (Conv2D)          │ (None, 8, 8, 144)            │             3,456 │ block_9_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_expand_BN                │ (None, 8, 8, 144)            │               576 │ block_10_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_expand_relu (ReLU)       │ (None, 8, 8, 144)            │                 0 │ block_10_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_depthwise                │ (None, 8, 8, 144)            │             1,296 │ block_10_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_depthwise_BN             │ (None, 8, 8, 144)            │               576 │ block_10_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_depthwise_relu (ReLU)    │ (None, 8, 8, 144)            │                 0 │ block_10_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_project (Conv2D)         │ (None, 8, 8, 32)             │             4,608 │ block_10_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_10_project_BN               │ (None, 8, 8, 32)             │               128 │ block_10_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_expand (Conv2D)          │ (None, 8, 8, 192)            │             6,144 │ block_10_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_expand_BN                │ (None, 8, 8, 192)            │               768 │ block_11_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_expand_relu (ReLU)       │ (None, 8, 8, 192)            │                 0 │ block_11_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_depthwise                │ (None, 8, 8, 192)            │             1,728 │ block_11_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_depthwise_BN             │ (None, 8, 8, 192)            │               768 │ block_11_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_depthwise_relu (ReLU)    │ (None, 8, 8, 192)            │                 0 │ block_11_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_project (Conv2D)         │ (None, 8, 8, 32)             │             6,144 │ block_11_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_project_BN               │ (None, 8, 8, 32)             │               128 │ block_11_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_11_add (Add)                │ (None, 8, 8, 32)             │                 0 │ block_10_project_BN[0][0],
# │                                   │                              │                   │ block_11_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_expand (Conv2D)          │ (None, 8, 8, 192)            │             6,144 │ block_11_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_expand_BN                │ (None, 8, 8, 192)            │               768 │ block_12_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_expand_relu (ReLU)       │ (None, 8, 8, 192)            │                 0 │ block_12_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_depthwise                │ (None, 8, 8, 192)            │             1,728 │ block_12_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_depthwise_BN             │ (None, 8, 8, 192)            │               768 │ block_12_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_depthwise_relu (ReLU)    │ (None, 8, 8, 192)            │                 0 │ block_12_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_project (Conv2D)         │ (None, 8, 8, 32)             │             6,144 │ block_12_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_project_BN               │ (None, 8, 8, 32)             │               128 │ block_12_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_12_add (Add)                │ (None, 8, 8, 32)             │                 0 │ block_11_add[0][0],
# │                                   │                              │                   │ block_12_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_expand (Conv2D)          │ (None, 8, 8, 192)            │             6,144 │ block_12_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_expand_BN                │ (None, 8, 8, 192)            │               768 │ block_13_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_expand_relu (ReLU)       │ (None, 8, 8, 192)            │                 0 │ block_13_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_pad (ZeroPadding2D)      │ (None, 9, 9, 192)            │                 0 │ block_13_expand_relu[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_depthwise                │ (None, 4, 4, 192)            │             1,728 │ block_13_pad[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_depthwise_BN             │ (None, 4, 4, 192)            │               768 │ block_13_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_depthwise_relu (ReLU)    │ (None, 4, 4, 192)            │                 0 │ block_13_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_project (Conv2D)         │ (None, 4, 4, 56)             │            10,752 │ block_13_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_13_project_BN               │ (None, 4, 4, 56)             │               224 │ block_13_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_expand (Conv2D)          │ (None, 4, 4, 336)            │            18,816 │ block_13_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_expand_BN                │ (None, 4, 4, 336)            │             1,344 │ block_14_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_expand_relu (ReLU)       │ (None, 4, 4, 336)            │                 0 │ block_14_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_depthwise                │ (None, 4, 4, 336)            │             3,024 │ block_14_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_depthwise_BN             │ (None, 4, 4, 336)            │             1,344 │ block_14_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_depthwise_relu (ReLU)    │ (None, 4, 4, 336)            │                 0 │ block_14_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_project (Conv2D)         │ (None, 4, 4, 56)             │            18,816 │ block_14_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_project_BN               │ (None, 4, 4, 56)             │               224 │ block_14_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_14_add (Add)                │ (None, 4, 4, 56)             │                 0 │ block_13_project_BN[0][0],
# │                                   │                              │                   │ block_14_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_expand (Conv2D)          │ (None, 4, 4, 336)            │            18,816 │ block_14_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_expand_BN                │ (None, 4, 4, 336)            │             1,344 │ block_15_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_expand_relu (ReLU)       │ (None, 4, 4, 336)            │                 0 │ block_15_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_depthwise                │ (None, 4, 4, 336)            │             3,024 │ block_15_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_depthwise_BN             │ (None, 4, 4, 336)            │             1,344 │ block_15_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_depthwise_relu (ReLU)    │ (None, 4, 4, 336)            │                 0 │ block_15_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_project (Conv2D)         │ (None, 4, 4, 56)             │            18,816 │ block_15_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_project_BN               │ (None, 4, 4, 56)             │               224 │ block_15_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_15_add (Add)                │ (None, 4, 4, 56)             │                 0 │ block_14_add[0][0],
# │                                   │                              │                   │ block_15_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_expand (Conv2D)          │ (None, 4, 4, 336)            │            18,816 │ block_15_add[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_expand_BN                │ (None, 4, 4, 336)            │             1,344 │ block_16_expand[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_expand_relu (ReLU)       │ (None, 4, 4, 336)            │                 0 │ block_16_expand_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_depthwise                │ (None, 4, 4, 336)            │             3,024 │ block_16_expand_relu[0][0]
# │ (DepthwiseConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_depthwise_BN             │ (None, 4, 4, 336)            │             1,344 │ block_16_depthwise[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_depthwise_relu (ReLU)    │ (None, 4, 4, 336)            │                 0 │ block_16_depthwise_BN[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_project (Conv2D)         │ (None, 4, 4, 112)            │            37,632 │ block_16_depthwise_relu[0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ block_16_project_BN               │ (None, 4, 4, 112)            │               448 │ block_16_project[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ Conv_1 (Conv2D)                   │ (None, 4, 4, 1280)           │           143,360 │ block_16_project_BN[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ Conv_1_bn (BatchNormalization)    │ (None, 4, 4, 1280)           │             5,120 │ Conv_1[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ out_relu (ReLU)                   │ (None, 4, 4, 1280)           │                 0 │ Conv_1_bn[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ global_average_pooling2d_6        │ (None, 1280)                 │                 0 │ out_relu[0][0]
# │ (GlobalAveragePooling2D)          │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_5             │ (None, 1280)                 │             5,120 │ global_average_pooling2d_6
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_6 (Dropout)               │ (None, 1280)                 │                 0 │ batch_normalization_5[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dense_6 (Dense)                   │ (None, 1)                    │             1,281 │ dropout_6[0][0]
# └───────────────────────────────────┴──────────────────────────────┴───────────────────┴───────────────────────────
#  Total params: 416,609 (1.59 MB)
#  Trainable params: 3,841 (15.00 KB)
#  Non-trainable params: 412,768 (1.57 MB)
# None

# %%
early = tf.keras.callbacks.EarlyStopping(
    monitor="val_auc", mode="max", patience=2, restore_best_weights=True
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=TOTAL_EPOCHS,
    callbacks=[early],
    class_weight=class_weight,   # None si balanceado
    verbose=1
)
# Out:
# Epoch 1/6
# 1146/1146 ━━━━━━━━━━━━━━━━━━━━ 114s 89ms/step - accuracy: 0.5686 - auc: 0.5943 - loss: 0.6762 - val_accuracy: 0.6606 - val_auc: 0.7227 - val_loss: 0.6185
# Epoch 2/6
#  936/1146 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.6394 - auc: 0.6946 - loss: 0.6310

# %%
fine_tune_at = max(0, len(model.layers) - 40)
for layer in model.layers[fine_tune_at:]:
    if hasattr(layer, "trainable"):
        layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=2e-4, weight_decay=5e-5),
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2,             # 1–2 es suficiente
    callbacks=[early],
    class_weight=class_weight,
    verbose=1
)

# %%
test_metrics = model.evaluate(test_ds, verbose=1)
print("Test metrics:", dict(zip(model.metrics_names, test_metrics)))

# %%
val_probs = model.predict(val_ds, verbose=0).ravel()
# Recupera etiquetas reales de val (ya las tienes en y_val):
y_val_true = np.array([dataset[i]["label"] for i in idx_val], dtype=np.int32)

# Busca umbral óptimo por accuracy (puedes cambiar a F1/AUC-Youden)
ths = np.linspace(0.1, 0.9, 81)
accs = [(th, ( (val_probs >= th).astype(int) == y_val_true ).mean()) for th in ths]
best_th, best_acc = max(accs, key=lambda x: x[1])
print(f"Umbral óptimo val: {best_th:.3f} (acc={best_acc:.3f})")

# Evalúa en test con ese umbral
test_probs = model.predict(test_ds, verbose=0).ravel()
y_test_true = np.array([dataset[i]["label"] for i in idx_test], dtype=np.int32)
test_pred = (test_probs >= best_th).astype(int)
test_acc = (test_pred == y_test_true).mean()
print(f"Test accuracy @th={best_th:.3f}: {test_acc:.3f}")
